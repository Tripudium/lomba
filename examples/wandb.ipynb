# %%
# %load_ext autoreload
# %autoreload 2

# %%
WB_API_KEY = "00e7f4c5450fcf5969642612ae0f2a5776fecc67"

# %%
import wandb
import random

# %%
wandb.login(key=WB_API_KEY)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /Users/u1774790/.netrc
# True

# %%
project = "my-first-project"

# %%
config = {
    "epochs": 10,
    "lr": 0.001,
}

# %%
with wandb.init(project=project, config=config) as run:
    run.log({"accuracy": 0.9, "loss": 0.1})
# Out:
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>/Users/u1774790/Tripudium/DS/lobgpt/examples/wandb/run-20251202_090233-jvjgfn2y</code>
# Syncing run <strong><a href='https://wandb.ai/tripudium-tripudium/my-first-project/runs/jvjgfn2y' target="_blank">different-spaceship-1</a></strong> to <a href='https://wandb.ai/tripudium-tripudium/my-first-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tripudium-tripudium/my-first-project' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project</a>
#  View run at <a href='https://wandb.ai/tripudium-tripudium/my-first-project/runs/jvjgfn2y' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project/runs/jvjgfn2y</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.9</td></tr><tr><td>loss</td><td>0.1</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">different-spaceship-1</strong> at: <a href='https://wandb.ai/tripudium-tripudium/my-first-project/runs/jvjgfn2y' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project/runs/jvjgfn2y</a><br> View project at: <a href='https://wandb.ai/tripudium-tripudium/my-first-project' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251202_090233-jvjgfn2y/logs</code>

# %%
with wandb.init(project=project, config=config) as run:
    offset = random.random() / 5
    print(f"lr: {config['lr']}")
    
    # Simulate a training run
    for epoch in range(2, config['epochs']):
        acc = 1 - 2**-config['epochs'] - random.random() / config['epochs'] - offset
        loss = 2**-config['epochs'] + random.random() / config['epochs'] + offset
        print(f"epoch={config['epochs']}, accuracy={acc}, loss={loss}")
        run.log({"accuracy": acc, "loss": loss})
# Out:
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>/Users/u1774790/Tripudium/DS/lobgpt/examples/wandb/run-20251202_103951-pjurbtco</code>
# Syncing run <strong><a href='https://wandb.ai/tripudium-tripudium/my-first-project/runs/pjurbtco' target="_blank">stellar-fog-4</a></strong> to <a href='https://wandb.ai/tripudium-tripudium/my-first-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tripudium-tripudium/my-first-project' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project</a>
#  View run at <a href='https://wandb.ai/tripudium-tripudium/my-first-project/runs/pjurbtco' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project/runs/pjurbtco</a>
# lr: 0.001
# epoch=10, accuracy=0.7963006957573344, loss=0.2768756014832642
# epoch=10, accuracy=0.7816269732439438, loss=0.27871091431543477
# epoch=10, accuracy=0.749181590300126, loss=0.2806365001338412
# epoch=10, accuracy=0.754441837464155, loss=0.20266874931072043
# epoch=10, accuracy=0.7240197233253853, loss=0.25925341159047527
# epoch=10, accuracy=0.7829531907750136, loss=0.21334463440856163
# epoch=10, accuracy=0.739253145588521, loss=0.23400214521299367
# epoch=10, accuracy=0.7592149067723974, loss=0.2624776566574412
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>█▇▃▄▁▇▂▄</td></tr><tr><td>loss</td><td>███▁▆▂▄▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.75921</td></tr><tr><td>loss</td><td>0.26248</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-fog-4</strong> at: <a href='https://wandb.ai/tripudium-tripudium/my-first-project/runs/pjurbtco' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project/runs/pjurbtco</a><br> View project at: <a href='https://wandb.ai/tripudium-tripudium/my-first-project' target="_blank">https://wandb.ai/tripudium-tripudium/my-first-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251202_103951-pjurbtco/logs</code>
